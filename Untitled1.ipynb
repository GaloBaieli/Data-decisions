# %%
import pandas as pd

# %%
import numpy as np

# %%
# %ls data/datasets/
# Out:
# adult.csv                  census.csv     movies.csv
# airline_data.csv           coches.csv     nhanes_2015_2016.csv
# antropometria00.csv        cwurData.csv   pokemon.csv
# antropometria-dataset.csv  data.csv       reg_data.csv
# Book3.csv                  headbrain.csv  sample_pivot.csv
# Canada.xlsx                mic2.xlsx      tips.csv
# Cartwheeldata.csv          mic.xlsx       weight-height.csv

# %%
df=pd.read_csv("data/datasets/antropometria-dataset.csv")

# %%
df.head(2)
# Out:
#     folio  intp  entidad desc_ent  sexo  edad  meses   peso  ropa  talla  ...  \
# 0  210295     2       21   PUEBLA     2    38      8  73.70     2  146.4  ...
# 1  101655     3       10  DURANGO     2    11     11  35.65     2  145.1  ...
#
#   hpresion tbrazo  htension  PrimaryLast  code_upm  est_dis est_urb est_marg  \
# 0    16:30      2     16:35            1     R2101        5       3        1
# 1    15:25      3     15:25            1     M1041        1       1        1
#
#         pondef  est_var
# 0  3470.002176      215
# 1   417.946672      101
#
# [2 rows x 26 columns]

# %%
df.describe()
# Out:
#                folio          intp       entidad          sexo          edad  \
# count   18640.000000  18640.000000  18640.000000  18640.000000  18640.000000
# mean   168011.824785      2.369260     16.699303      1.562554     34.379667
# std     93138.323007      1.395643      9.315979      0.496085     20.083770
# min     10001.000000      1.000000      1.000000      1.000000     10.000000
# 25%     82080.250000      1.000000      8.000000      1.000000     16.000000
# 50%    170964.000000      2.000000     17.000000      2.000000     31.000000
# 75%    250384.250000      3.000000     25.000000      2.000000     48.000000
# max    321861.000000     13.000000     32.000000      2.000000    104.000000
#
#               meses          peso          ropa         talla       cintura  \
# count  18640.000000  18640.000000  18640.000000  18640.000000  18032.000000
# mean       5.418670     64.638707      1.566148    156.558291     87.778529
# ...

# %%
pd.pivot_table(df,
               index= ['desc_ent'],
               aggfunc= ['mean'],
               values= ['peso'],
               margins= True
              )
# Out:
#                                       mean
#                                       peso
# desc_ent
# AGUASCALIENTES                   66.357786
# BAJA CALIFORNIA                  68.467270
# BAJA CALIFORNIA SUR              71.809198
# CAMPECHE                         65.418475
# CHIAPAS                          57.613775
# CHIHUAHUA                        66.656005
# COAHUILA DE ZARAGOZA             68.154142
# COLIMA                           68.743648
# DISTRITO FEDERAL                 65.119273
# DURANGO                          66.354922
# GUANAJUATO                       63.936390
# GUERRERO                         60.466315
# HIDALGO                          59.995917
# JALISCO                          66.697270
# MEXICO                           60.680850
# MICHOACAN DE OCAMPO              64.900000
# MORELOS                          63.541295
# NAYARIT                          66.541827
# NUEVO LEON                       67.239853
# ...

# %%
pd.pivot_table(df,
               index= ['desc_ent','sexo'],
               aggfunc= ['median'],
               values= ['peso'],
               margins= True
              )
# Out:
#                           median
#                             peso
# desc_ent            sexo
# AGUASCALIENTES      1     69.950
#                     2     63.700
# BAJA CALIFORNIA     1     70.650
#                     2     64.200
# BAJA CALIFORNIA SUR 1     76.650
# ...                          ...
# YUCATAN             1     66.000
#                     2     59.575
# ZACATECAS           1     65.300
#                     2     61.625
# All                       63.700
#
# [65 rows x 1 columns]

# %%
pd.pivot_table(df,
               index= ['desc_ent','sexo'],
               aggfunc= ['median'],
               values= ['peso'],
               margins= True
              )
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_61/3539719579.py in <module>
#       4                values= ['age','hours-per-week'],
#       5                columns='sex',
# ----> 6                margins= True,
#       7               )
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#      54                 dropna=dropna,
#      55                 margins_name=margins_name,
# ---> 56                 observed=observed,
#      57             )
#      58             pieces.append(table)
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/pandas/core/reshape/pivot.py in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed)
#      75         for i in values:
# ...

# %%
pd.pivot_table(df,
               index= ['desc_ent','sexo'],
               aggfunc= ['mean'],
               values= ['peso'],
               margins= True
              )
# Out:
#                                mean
#                                peso
# desc_ent            sexo
# AGUASCALIENTES      1     69.985381
#                     2     63.254292
# BAJA CALIFORNIA     1     71.391818
#                     2     65.893667
# BAJA CALIFORNIA SUR 1     75.561015
# ...                             ...
# YUCATAN             1     65.717541
#                     2     60.537515
# ZACATECAS           1     66.096483
#                     2     62.757788
# All                       64.638707
#
# [65 rows x 1 columns]

# %%
df=pd.read_csv("data/datasets/adult.csv")

# %%
df.head(2)
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
#
#         marital-status        occupation    relationship    race    sex  \
# 0        Never-married      Adm-clerical   Not-in-family   White   Male
# 1   Married-civ-spouse   Exec-managerial         Husband   White   Male
#
#    capital-gain  capital-loss  hours-per-week  native-country the label
# 0          2174             0              40   United-States     <=50K
# 1             0             0              13   United-States     <=50K

# %%
pd.pivot_table(df,
               index= ['education'],
               aggfunc= ['mean'],
               values= ['age'],
               columns= 'marital-status',
               margins= True
              )
# Out:
#                      mean                                         \
#                       age
# marital-status   Divorced  Married-AF-spouse  Married-civ-spouse
# education
#  10th           44.133333                NaN           46.126074
#  11th           41.230769                NaN           42.559322
#  12th           41.333333                NaN           41.892308
#  1st-4th        62.700000                NaN           47.888889
#  5th-6th        53.700000                NaN           45.872093
#  7th-8th        49.452055                NaN           50.601671
#  9th            46.281250                NaN           45.886957
#  Assoc-acdm     41.064039          31.500000           40.617391
#  Assoc-voc      40.653846          29.000000           40.719884
#  Bachelors      44.243590          30.750000           42.648121
#  Doctorate      49.303030                NaN           48.786713
#  HS-grad        42.363918          34.615385           42.817131
# ...

# %%
pd.pivot_table(df,
               index= ['education','marital-status'],
               aggfunc= ['median'],
               values= ['age','hours-per-week'],
               columns= 'sex',
               margins= True
              )
# Out:
#                                       median                                   \
#                                          age             hours-per-week
# sex                                   Female  Male   All         Female  Male
# education     marital-status
#  10th          Divorced                 45.0  39.0  40.5           40.0  40.0
#                Married-civ-spouse       32.0  48.0  48.0           40.0  40.0
#                Married-spouse-absent    39.0  49.0  44.0           40.0  40.0
#                Never-married            18.0  20.0  19.0           26.5  40.0
#                Separated                34.0  38.0  38.0           40.0  40.0
# ...                                      ...   ...   ...            ...   ...
#  Some-college  Married-spouse-absent    31.0  37.0  34.5           40.0  40.0
#                Never-married            22.0  23.0  22.0           35.0  40.0
#                Separated                38.0  37.0  37.0           40.0  40.0
# ...
